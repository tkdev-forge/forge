# %% [markdown]
# # Learning Curves Analysis
# Load `efficiency_measurements` data and compare control vs treatment trends.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# TODO: wire DB connection and query efficiency_measurements
